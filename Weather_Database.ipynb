# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy
import random

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)
lat_lngs

# %%
# Get the nearest city using the citipy module
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 705

# %%
from config import weather_api_key

# %%
#Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %%
# create an empty list to hold the weather daya.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + cities[i]
    

for i, city in enumerate(cities):

    
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Retrieve lat and long, max temp, % humidity, % cloudness, wind speed, and weather description
    try:
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 15 | terekli-mekteb
# Processing Record 2 of Set 15 | port elizabeth
# Processing Record 3 of Set 15 | ponta delgada
# Processing Record 4 of Set 15 | atuona
# Processing Record 5 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 15 | rikitea
# Processing Record 7 of Set 15 | qaanaaq
# Processing Record 8 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 15 | dingle
# Processing Record 10 of Set 15 | tabou
# Processing Record 11 of Set 15 | punta arenas
# Processing Record 12 of Set 15 | waingapu
# Processing Record 13 of Set 15 | bintulu
# Processing Record 14 of Set 15 | pisco
# Processing Record 15 of Set 15 | tokomaru
# Processing Record 16 of Set 15 | ushuaia
# Processing Record 17 of Set 15 | nikolskoye
# Processing Record 18 of Set 15 | san cosme y damian
# Processing Record 19 of Set 15 | mataura
# Processing Record 20 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 15 | chuy
# Processing Record 22 of Set 15 | hambantota
# Processing Record 23 of Set 15 | carnarvon
# Processing Record 24 of Set 15 | sambava
# Processing Record 25 of Set 15 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 15 | castro
# Processing Record 27 of Set 15 | jamestown
# Processing Record 28 of Set 15 | lubango
# Processing Record 29 of Set 15 | karabuk
# Processing Record 30 of Set 15 | port alfred
# Processing Record 31 of Set 15 | saint george
# Processing Record 32 of Set 15 | chokurdakh
# Processing Record 33 of Set 15 | new norfolk
# Processing Record 34 of Set 15 | hobart
# Processing Record 35 of Set 15 | busselton
# Processing Record 36 of Set 15 | albany
# Processing Record 37 of Set 15 | saskylakh
# Processing Record 38 of Set 15 | raga
# Processing Record 39 of Set 15 | saint-philippe
# Processing Record 40 of Set 15 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 15 | alofi
# Processing Record 42 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 15 | mahebourg
# Processing Record 44 of Set 15 | isangel
# Processing Record 45 of Set 15 | salalah
# Processing Record 46 of Set 15 | leningradskiy
# Processing Record 47 of Set 15 | vila
# Processing Record 48 of Set 15 | bredasdorp
# Processing Record 49 of Set 15 | kodinsk
# Processing Record 50 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 16 | cherskiy
# Processing Record 2 of Set 16 | kapaa
# Processing Record 3 of Set 16 | yulara
# Processing Record 4 of Set 16 | guerrero negro
# Processing Record 5 of Set 16 | caravelas
# Processing Record 6 of Set 16 | narsaq
# Processing Record 7 of Set 16 | matara
# Processing Record 8 of Set 16 | hilo
# Processing Record 9 of Set 16 | la ronge
# Processing Record 10 of Set 16 | hami
# Processing Record 11 of Set 16 | east london
# Processing Record 12 of Set 16 | guantanamo
# Processing Record 13 of Set 16 | san quintin
# Processing Record 14 of Set 16 | deputatskiy
# Processing Record 15 of Set 16 | ribeira grande
# Processing Record 16 of Set 16 | north bend
# Processing Record 17 of Set 16 | norman wells
# Processing Record 18 of Set 16 | acapulco
# Processing Record 19 of Set 16 | port blair
# Processing Record 20 of Set 16 | abbeville
# Processing Record 21 of Set 16 | hermanus
# Processing Record 22 of Set 16 | beringovskiy
# Processing Record 23 of Set 16 | turukhansk
# Processing Record 24 of Set 16 | nouakchott
# Processing Record 25 of Set 16 | lermontovka
# Processing Record 26 of Set 16 | yellowknife
# Processing Record 27 of Set 16 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 16 | yongan
# Processing Record 29 of Set 16 | saint-pierre
# Processing Record 30 of Set 16 | barrow
# Processing Record 31 of Set 16 | kysyl-syr
# Processing Record 32 of Set 16 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 16 | cabo san lucas
# Processing Record 34 of Set 16 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 16 | lebu
# Processing Record 36 of Set 16 | avarua
# Processing Record 37 of Set 16 | college
# Processing Record 38 of Set 16 | keningau
# Processing Record 39 of Set 16 | butaritari
# Processing Record 40 of Set 16 | awjilah
# Processing Record 41 of Set 16 | sinnamary
# Processing Record 42 of Set 16 | juneau
# Processing Record 43 of Set 16 | makakilo city
# Processing Record 44 of Set 16 | bambous virieux
# Processing Record 45 of Set 16 | harper
# Processing Record 46 of Set 16 | severo-kurilsk
# Processing Record 47 of Set 16 | scottsburgh
# City not found. Skipping...
# Processing Record 48 of Set 16 | satna
# Processing Record 49 of Set 16 | linjiang
# Processing Record 50 of Set 16 | upernavik
# Processing Record 1 of Set 17 | parlakimidi
# Processing Record 2 of Set 17 | provideniya
# Processing Record 3 of Set 17 | vestmannaeyjar
# Processing Record 4 of Set 17 | saint-joseph
# Processing Record 5 of Set 17 | ust-maya
# Processing Record 6 of Set 17 | san felipe
# Processing Record 7 of Set 17 | valdivia
# Processing Record 8 of Set 17 | lompoc
# Processing Record 9 of Set 17 | cam ranh
# Processing Record 10 of Set 17 | grootfontein
# Processing Record 11 of Set 17 | nuuk
# Processing Record 12 of Set 17 | ostrovnoy
# Processing Record 13 of Set 17 | ilulissat
# Processing Record 14 of Set 17 | hithadhoo
# Processing Record 15 of Set 17 | cabra
# Processing Record 16 of Set 17 | sungaipenuh
# Processing Record 17 of Set 17 | khilok
# Processing Record 18 of Set 17 | georgetown
# Processing Record 19 of Set 17 | pangkalanbuun
# Processing Record 20 of Set 17 | stoyba
# City not found. Skipping...
# Processing Record 21 of Set 17 | kodiak
# Processing Record 22 of Set 17 | tuktoyaktuk
# Processing Record 23 of Set 17 | cape town
# Processing Record 24 of Set 17 | pangnirtung
# Processing Record 25 of Set 17 | saldanha
# Processing Record 26 of Set 17 | pitimbu
# Processing Record 27 of Set 17 | komsomolskiy
# Processing Record 28 of Set 17 | puerto ayora
# Processing Record 29 of Set 17 | maniitsoq
# Processing Record 30 of Set 17 | necochea
# Processing Record 31 of Set 17 | marrakesh
# Processing Record 32 of Set 17 | gulshat
# City not found. Skipping...
# Processing Record 33 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 17 | banikoara
# Processing Record 35 of Set 17 | ust-kuyga
# Processing Record 36 of Set 17 | pacific grove
# Processing Record 37 of Set 17 | victoria
# Processing Record 38 of Set 17 | sorong
# Processing Record 39 of Set 17 | sao jose da coroa grande
# Processing Record 40 of Set 17 | sur
# Processing Record 41 of Set 17 | longyearbyen
# Processing Record 42 of Set 17 | pingliang
# Processing Record 43 of Set 17 | teguise
# Processing Record 44 of Set 17 | bandarbeyla
# Processing Record 45 of Set 17 | ust-nera
# Processing Record 46 of Set 17 | kloulklubed
# Processing Record 47 of Set 17 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 17 | ambodifototra
# City not found. Skipping...
# Processing Record 49 of Set 17 | dawson
# Processing Record 50 of Set 17 | dikson
# Processing Record 1 of Set 18 | banmo
# City not found. Skipping...
# Processing Record 2 of Set 18 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 18 | machhlishahr
# Processing Record 4 of Set 18 | kulhudhuffushi
# Processing Record 5 of Set 18 | tiarei
# Processing Record 6 of Set 18 | airai
# Processing Record 7 of Set 18 | ngunguru
# Processing Record 8 of Set 18 | zherdevka
# Processing Record 9 of Set 18 | san cristobal
# Processing Record 10 of Set 18 | waitati
# Processing Record 11 of Set 18 | kaitangata
# Processing Record 12 of Set 18 | tezu
# Processing Record 13 of Set 18 | khatanga
# Processing Record 14 of Set 18 | yatou
# Processing Record 15 of Set 18 | lagoa
# Processing Record 16 of Set 18 | san patricio
# Processing Record 17 of Set 18 | ojinaga
# Processing Record 18 of Set 18 | vaini
# Processing Record 19 of Set 18 | moussoro
# Processing Record 20 of Set 18 | saravena
# Processing Record 21 of Set 18 | mugur-aksy
# Processing Record 22 of Set 18 | yuli
# Processing Record 23 of Set 18 | macusani
# Processing Record 24 of Set 18 | walvis bay
# Processing Record 25 of Set 18 | mabaruma
# Processing Record 26 of Set 18 | arraial do cabo
# Processing Record 27 of Set 18 | mayumba
# Processing Record 28 of Set 18 | bukachacha
# Processing Record 29 of Set 18 | sioux lookout
# Processing Record 30 of Set 18 | trincomalee
# Processing Record 31 of Set 18 | onguday
# Processing Record 32 of Set 18 | sangueya
# Processing Record 33 of Set 18 | ormara
# Processing Record 34 of Set 18 | bluff
# Processing Record 35 of Set 18 | tasiilaq
# Processing Record 36 of Set 18 | daru
# Processing Record 37 of Set 18 | ust-kan
# Processing Record 38 of Set 18 | thompson
# Processing Record 39 of Set 18 | camacha
# Processing Record 40 of Set 18 | bahir dar
# Processing Record 41 of Set 18 | vaitupu
# City not found. Skipping...
# Processing Record 42 of Set 18 | yambio
# Processing Record 43 of Set 18 | itoman
# Processing Record 44 of Set 18 | aksu
# Processing Record 45 of Set 18 | la tuque
# Processing Record 46 of Set 18 | torbay
# Processing Record 47 of Set 18 | norilsk
# Processing Record 48 of Set 18 | henties bay
# Processing Record 49 of Set 18 | lavrentiya
# Processing Record 50 of Set 18 | katsuura
# Processing Record 1 of Set 19 | guanica
# Processing Record 2 of Set 19 | impfondo
# Processing Record 3 of Set 19 | menongue
# Processing Record 4 of Set 19 | bethel
# Processing Record 5 of Set 19 | ewa beach
# Processing Record 6 of Set 19 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 19 | porto novo
# Processing Record 8 of Set 19 | gusau
# Processing Record 9 of Set 19 | peniche
# Processing Record 10 of Set 19 | presidencia roque saenz pena
# Processing Record 11 of Set 19 | maligaya
# Processing Record 12 of Set 19 | ballina
# Processing Record 13 of Set 19 | souillac
# Processing Record 14 of Set 19 | ulladulla
# Processing Record 15 of Set 19 | bereda
# Processing Record 16 of Set 19 | bangassou
# Processing Record 17 of Set 19 | sorland
# Processing Record 18 of Set 19 | abalak
# Processing Record 19 of Set 19 | sol-iletsk
# Processing Record 20 of Set 19 | port moresby
# Processing Record 21 of Set 19 | ambositra
# Processing Record 22 of Set 19 | hirara
# Processing Record 23 of Set 19 | chivay
# Processing Record 24 of Set 19 | mar del plata
# Processing Record 25 of Set 19 | poum
# Processing Record 26 of Set 19 | rockhampton
# Processing Record 27 of Set 19 | hay river
# Processing Record 28 of Set 19 | ponta do sol
# Processing Record 29 of Set 19 | salym
# Processing Record 30 of Set 19 | the pas
# Processing Record 31 of Set 19 | ossora
# Processing Record 32 of Set 19 | mayo
# Processing Record 33 of Set 19 | rawson
# Processing Record 34 of Set 19 | sitka
# Processing Record 35 of Set 19 | muleba
# Processing Record 36 of Set 19 | olga
# Processing Record 37 of Set 19 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 19 | hasaki
# Processing Record 39 of Set 19 | saint-francois
# Processing Record 40 of Set 19 | boende
# Processing Record 41 of Set 19 | kushima
# Processing Record 42 of Set 19 | zverinogolovskoye
# Processing Record 43 of Set 19 | sangre grande
# Processing Record 44 of Set 19 | ruidoso
# Processing Record 45 of Set 19 | vila franca do campo
# Processing Record 46 of Set 19 | grindu
# Processing Record 47 of Set 19 | goderich
# Processing Record 48 of Set 19 | bayevo
# Processing Record 49 of Set 19 | aklavik
# Processing Record 50 of Set 19 | noyabrsk
# Processing Record 1 of Set 20 | clyde river
# Processing Record 2 of Set 20 | murchison
# Processing Record 3 of Set 20 | zhengjiatun
# Processing Record 4 of Set 20 | suntar
# Processing Record 5 of Set 20 | grindavik
# Processing Record 6 of Set 20 | tilichiki
# Processing Record 7 of Set 20 | dickinson
# Processing Record 8 of Set 20 | ongandjera
# Processing Record 9 of Set 20 | farrukhnagar
# Processing Record 10 of Set 20 | terrace
# Processing Record 11 of Set 20 | atar
# Processing Record 12 of Set 20 | hofn
# Processing Record 13 of Set 20 | mumford
# Processing Record 14 of Set 20 | locri
# Processing Record 15 of Set 20 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 20 | saryshagan
# City not found. Skipping...
# Processing Record 17 of Set 20 | kahului
# Processing Record 18 of Set 20 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 20 | pevek
# Processing Record 20 of Set 20 | nyrob
# Processing Record 21 of Set 20 | gamba
# Processing Record 22 of Set 20 | kedrovyy
# Processing Record 23 of Set 20 | port macquarie
# Processing Record 24 of Set 20 | port hardy
# Processing Record 25 of Set 20 | birjand
# Processing Record 26 of Set 20 | esperance
# Processing Record 27 of Set 20 | sisimiut
# Processing Record 28 of Set 20 | talnakh
# Processing Record 29 of Set 20 | teluknaga
# Processing Record 30 of Set 20 | morehead
# Processing Record 31 of Set 20 | san ignacio
# Processing Record 32 of Set 20 | hobyo
# Processing Record 33 of Set 20 | bathsheba
# Processing Record 34 of Set 20 | waddan
# Processing Record 35 of Set 20 | faanui
# Processing Record 36 of Set 20 | aksay
# Processing Record 37 of Set 20 | pasaco
# Processing Record 38 of Set 20 | solnechnyy
# Processing Record 39 of Set 20 | bilibino
# Processing Record 40 of Set 20 | te anau
# Processing Record 41 of Set 20 | morant bay
# Processing Record 42 of Set 20 | preeceville
# Processing Record 43 of Set 20 | iqaluit
# Processing Record 44 of Set 20 | ahipara
# Processing Record 45 of Set 20 | flinders
# Processing Record 46 of Set 20 | alice springs
# Processing Record 47 of Set 20 | rascani
# City not found. Skipping...
# Processing Record 48 of Set 20 | joshimath
# Processing Record 49 of Set 20 | krasnyy oktyabr
# Processing Record 50 of Set 20 | almaznyy
# Processing Record 1 of Set 21 | dubbo
# Processing Record 2 of Set 21 | katangli
# Processing Record 3 of Set 21 | moose factory
# Processing Record 4 of Set 21 | shimanovsk
# Processing Record 5 of Set 21 | chingola
# Processing Record 6 of Set 21 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 21 | nanortalik
# Processing Record 8 of Set 21 | nusaybin
# Processing Record 9 of Set 21 | klaksvik
# Processing Record 10 of Set 21 | bonthe
# Processing Record 11 of Set 21 | puerto suarez
# Processing Record 12 of Set 21 | clearlake
# Processing Record 13 of Set 21 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 21 | bisira
# Processing Record 15 of Set 21 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 21 | yar-sale
# Processing Record 17 of Set 21 | illapel
# Processing Record 18 of Set 21 | codrington
# Processing Record 19 of Set 21 | bandarban
# Processing Record 20 of Set 21 | nouadhibou
# Processing Record 21 of Set 21 | kamen-rybolov
# Processing Record 22 of Set 21 | margate
# Processing Record 23 of Set 21 | castelo
# Processing Record 24 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 21 | buraydah
# Processing Record 26 of Set 21 | olafsvik
# Processing Record 27 of Set 21 | karpogory
# Processing Record 28 of Set 21 | palaikastron
# Processing Record 29 of Set 21 | nome
# Processing Record 30 of Set 21 | kupino
# Processing Record 31 of Set 21 | raudeberg
# Processing Record 32 of Set 21 | qaqortoq
# Processing Record 33 of Set 21 | grand gaube
# Processing Record 34 of Set 21 | berdigestyakh
# Processing Record 35 of Set 21 | dunedin
# Processing Record 36 of Set 21 | bataipora
# Processing Record 37 of Set 21 | naron
# Processing Record 38 of Set 21 | antalaha
# Processing Record 39 of Set 21 | san javier
# Processing Record 40 of Set 21 | verkhnyaya inta
# Processing Record 41 of Set 21 | ternate
# Processing Record 42 of Set 21 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 21 | tocopilla
# Processing Record 44 of Set 21 | songkhla
# Processing Record 45 of Set 21 | tiksi
# Processing Record 46 of Set 21 | zambezi
# Processing Record 47 of Set 21 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 21 | katobu
# Processing Record 49 of Set 21 | srednekolymsk
# Processing Record 50 of Set 21 | sola
# Processing Record 1 of Set 22 | artyom
# Processing Record 2 of Set 22 | vallenar
# Processing Record 3 of Set 22 | nalut
# Processing Record 4 of Set 22 | okhotsk
# Processing Record 5 of Set 22 | volkhov
# Processing Record 6 of Set 22 | biggar
# Processing Record 7 of Set 22 | hihifo
# City not found. Skipping...
# Processing Record 8 of Set 22 | palmer
# Processing Record 9 of Set 22 | honiara
# Processing Record 10 of Set 22 | sibolga
# Processing Record 11 of Set 22 | paso de los toros
# Processing Record 12 of Set 22 | kavieng
# Processing Record 13 of Set 22 | kruisfontein
# Processing Record 14 of Set 22 | koumac
# Processing Record 15 of Set 22 | malakal
# Processing Record 16 of Set 22 | itarema
# Processing Record 17 of Set 22 | nemuro
# Processing Record 18 of Set 22 | pangai
# Processing Record 19 of Set 22 | sonipat
# Processing Record 20 of Set 22 | kukuna
# Processing Record 21 of Set 22 | atambua
# Processing Record 22 of Set 22 | saint anthony
# Processing Record 23 of Set 22 | elizabeth city
# Processing Record 24 of Set 22 | sarkand
# Processing Record 25 of Set 22 | kununurra
# Processing Record 26 of Set 22 | riviere-du-loup
# Processing Record 27 of Set 22 | roebourne
# Processing Record 28 of Set 22 | krasnoselkup
# Processing Record 29 of Set 22 | meulaboh
# Processing Record 30 of Set 22 | magadan
# Processing Record 31 of Set 22 | satipo
# Processing Record 32 of Set 22 | dzilam gonzalez
# Processing Record 33 of Set 22 | podosinovets
# Processing Record 34 of Set 22 | lancaster
# Processing Record 35 of Set 22 | mount gambier
# Processing Record 36 of Set 22 | vila velha
# Processing Record 37 of Set 22 | batagay
# Processing Record 38 of Set 22 | sao filipe
# Processing Record 39 of Set 22 | harunabad
# Processing Record 40 of Set 22 | viedma
# Processing Record 41 of Set 22 | manado
# Processing Record 42 of Set 22 | hovd
# Processing Record 43 of Set 22 | touros
# Processing Record 44 of Set 22 | lima
# Processing Record 45 of Set 22 | totness
# Processing Record 46 of Set 22 | carupano
# Processing Record 47 of Set 22 | naze
# Processing Record 48 of Set 22 | stepnyak
# Processing Record 49 of Set 22 | kiruna
# Processing Record 50 of Set 22 | berlevag
# Processing Record 1 of Set 23 | umzimvubu
# City not found. Skipping...
# Processing Record 2 of Set 23 | omboue
# Processing Record 3 of Set 23 | anchorage
# Processing Record 4 of Set 23 | wilmington
# Processing Record 5 of Set 23 | jumla
# Processing Record 6 of Set 23 | lorengau
# Processing Record 7 of Set 23 | iskateley
# Processing Record 8 of Set 23 | taoudenni
# Processing Record 9 of Set 23 | zhuhai
# Processing Record 10 of Set 23 | utiroa
# City not found. Skipping...
# Processing Record 11 of Set 23 | berezanka
# Processing Record 12 of Set 23 | emborion
# Processing Record 13 of Set 23 | fulacunda
# City not found. Skipping...
# Processing Record 14 of Set 23 | luderitz
# Processing Record 15 of Set 23 | solovetskiy
# City not found. Skipping...
# Processing Record 16 of Set 23 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 23 | marfino
# Processing Record 18 of Set 23 | milkovo
# Processing Record 19 of Set 23 | byron bay
# Processing Record 20 of Set 23 | fallon
# Processing Record 21 of Set 23 | homer
# Processing Record 22 of Set 23 | rodrigues alves
# Processing Record 23 of Set 23 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 23 | taywarah
# Processing Record 25 of Set 23 | bitkine
# Processing Record 26 of Set 23 | trairi
# Processing Record 27 of Set 23 | galesong
# Processing Record 28 of Set 23 | paamiut
# Processing Record 29 of Set 23 | kokopo
# Processing Record 30 of Set 23 | williams lake
# Processing Record 31 of Set 23 | cullman
# Processing Record 32 of Set 23 | vilani
# Processing Record 33 of Set 23 | amapa
# Processing Record 34 of Set 23 | petropavlovka
# Processing Record 35 of Set 23 | kalangala
# Processing Record 36 of Set 23 | puerto baquerizo moreno
# Processing Record 37 of Set 23 | rayong
# Processing Record 38 of Set 23 | sao joao da barra
# Processing Record 39 of Set 23 | los llanos de aridane
# Processing Record 40 of Set 23 | radzionkow
# Processing Record 41 of Set 23 | sept-iles
# Processing Record 42 of Set 23 | oranjemund
# Processing Record 43 of Set 23 | murgab
# Processing Record 44 of Set 23 | namibe
# Processing Record 45 of Set 23 | ambon
# Processing Record 46 of Set 23 | xam nua
# Processing Record 47 of Set 23 | cayenne
# Processing Record 48 of Set 23 | rodez
# Processing Record 49 of Set 23 | muhos
# Processing Record 50 of Set 23 | constitucion
# Processing Record 1 of Set 24 | khani
# Processing Record 2 of Set 24 | lexington
# Processing Record 3 of Set 24 | umm kaddadah
# Processing Record 4 of Set 24 | krasnovishersk
# Processing Record 5 of Set 24 | acari
# Processing Record 6 of Set 24 | kavaratti
# Processing Record 7 of Set 24 | hamilton
# Processing Record 8 of Set 24 | marystown
# Processing Record 9 of Set 24 | zhigansk
# Processing Record 10 of Set 24 | sidi ali
# Processing Record 11 of Set 24 | husavik
# Processing Record 12 of Set 24 | vostok
# Processing Record 13 of Set 24 | labuhan
# Processing Record 14 of Set 24 | baruun-urt
# Processing Record 15 of Set 24 | independence
# Processing Record 16 of Set 24 | vardo
# Processing Record 17 of Set 24 | tiznit
# Processing Record 18 of Set 24 | katsiveli
# City not found. Skipping...
# Processing Record 19 of Set 24 | pangody
# Processing Record 20 of Set 24 | praya
# Processing Record 21 of Set 24 | luklukan
# Processing Record 22 of Set 24 | talaya
# Processing Record 23 of Set 24 | kalianget
# Processing Record 24 of Set 24 | bonavista
# Processing Record 25 of Set 24 | namatanai
# Processing Record 26 of Set 24 | ixtapa
# Processing Record 27 of Set 24 | bartica
# Processing Record 28 of Set 24 | alotenango
# Processing Record 29 of Set 24 | coronado
# Processing Record 30 of Set 24 | hudson bay
# Processing Record 31 of Set 24 | lebyazhye
# Processing Record 32 of Set 24 | mackenzie
# Processing Record 33 of Set 24 | khoy
# Processing Record 34 of Set 24 | el alto
# Processing Record 35 of Set 24 | qui nhon
# Processing Record 36 of Set 24 | baykit
# Processing Record 37 of Set 24 | muriwai beach
# Processing Record 38 of Set 24 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 24 | opuwo
# Processing Record 40 of Set 24 | bababe
# City not found. Skipping...
# Processing Record 41 of Set 24 | yamada
# Processing Record 42 of Set 24 | kirkuk
# Processing Record 43 of Set 24 | otane
# Processing Record 44 of Set 24 | marawi
# Processing Record 45 of Set 24 | port-gentil
# Processing Record 46 of Set 24 | kuryk
# Processing Record 47 of Set 24 | narrabri
# Processing Record 48 of Set 24 | beidao
# Processing Record 49 of Set 24 | eidfjord
# Processing Record 50 of Set 24 | safranbolu
# Processing Record 1 of Set 25 | port lincoln
# Processing Record 2 of Set 25 | fairbanks
# Processing Record 3 of Set 25 | djibo
# Processing Record 4 of Set 25 | bar harbor
# Processing Record 5 of Set 25 | bengkulu
# Processing Record 6 of Set 25 | fortuna
# Processing Record 7 of Set 25 | dzhusaly
# City not found. Skipping...
# Processing Record 8 of Set 25 | eyl
# Processing Record 9 of Set 25 | pincher creek
# Processing Record 10 of Set 25 | chiredzi
# Processing Record 11 of Set 25 | chingirlau
# Processing Record 12 of Set 25 | syasstroy
# Processing Record 13 of Set 25 | tarpon springs
# Processing Record 14 of Set 25 | tazovskiy
# Processing Record 15 of Set 25 | podbrdo
# Processing Record 16 of Set 25 | hochst
# Processing Record 17 of Set 25 | mount isa
# Processing Record 18 of Set 25 | nazarovo
# Processing Record 19 of Set 25 | seoul
# Processing Record 20 of Set 25 | salas
# Processing Record 21 of Set 25 | carauari
# Processing Record 22 of Set 25 | islamkot
# Processing Record 23 of Set 25 | ketchikan
# Processing Record 24 of Set 25 | zhanaozen
# Processing Record 25 of Set 25 | rundu
# Processing Record 26 of Set 25 | togul
# Processing Record 27 of Set 25 | bien hoa
# Processing Record 28 of Set 25 | fare
# Processing Record 29 of Set 25 | san policarpo
# Processing Record 30 of Set 25 | chokwe
# Processing Record 31 of Set 25 | stornoway
# Processing Record 32 of Set 25 | kenai
# Processing Record 33 of Set 25 | batemans bay
# Processing Record 34 of Set 25 | skibbereen
# Processing Record 35 of Set 25 | zhezkazgan
# Processing Record 36 of Set 25 | dourbali
# Processing Record 37 of Set 25 | forestville
# Processing Record 38 of Set 25 | angoche
# Processing Record 39 of Set 25 | the valley
# Processing Record 40 of Set 25 | yakeshi
# Processing Record 41 of Set 25 | weligama
# Processing Record 42 of Set 25 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 25 | santa barbara
# Processing Record 44 of Set 25 | cockburn town
# Processing Record 45 of Set 25 | cidreira
# Processing Record 46 of Set 25 | hudiksvall
# Processing Record 47 of Set 25 | abu samrah
# Processing Record 48 of Set 25 | yinchuan
# Processing Record 49 of Set 25 | ardakan
# Processing Record 50 of Set 25 | yangambi
# Processing Record 1 of Set 26 | dryden
# Processing Record 2 of Set 26 | cody
# Processing Record 3 of Set 26 | bonnyville
# Processing Record 4 of Set 26 | washington
# Processing Record 5 of Set 26 | nichlaul
# Processing Record 6 of Set 26 | coromandel
# Processing Record 7 of Set 26 | wuwei
# Processing Record 8 of Set 26 | beisfjord
# Processing Record 9 of Set 26 | phuket
# Processing Record 10 of Set 26 | two rivers
# Processing Record 11 of Set 26 | kismayo
# Processing Record 12 of Set 26 | blind river
# Processing Record 13 of Set 26 | ugoofaaru
# Processing Record 14 of Set 26 | puerto guzman
# Processing Record 15 of Set 26 | kadykchan
# City not found. Skipping...
# Processing Record 16 of Set 26 | koutsouras
# Processing Record 17 of Set 26 | phan rang
# City not found. Skipping...
# Processing Record 18 of Set 26 | baijiantan
# Processing Record 19 of Set 26 | mineiros
# Processing Record 20 of Set 26 | rio claro
# Processing Record 21 of Set 26 | fukue
# Processing Record 22 of Set 26 | quetta
# Processing Record 23 of Set 26 | lata
# Processing Record 24 of Set 26 | luwuk
# Processing Record 25 of Set 26 | cairns
# Processing Record 26 of Set 26 | karkaralinsk
# City not found. Skipping...
# Processing Record 27 of Set 26 | ganta
# Processing Record 28 of Set 26 | sanawad
# Processing Record 29 of Set 26 | marienburg
# Processing Record 30 of Set 26 | tommot
# Processing Record 31 of Set 26 | bose
# Processing Record 32 of Set 26 | naustdal
# Processing Record 33 of Set 26 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 26 | port said
# Processing Record 35 of Set 26 | tapaua
# City not found. Skipping...
# Processing Record 36 of Set 26 | praia
# Processing Record 37 of Set 26 | xichang
# Processing Record 38 of Set 26 | tessalit
# Processing Record 39 of Set 26 | hattiesburg
# Processing Record 40 of Set 26 | mawlaik
# Processing Record 41 of Set 26 | nelson bay
# Processing Record 42 of Set 26 | burbach
# Processing Record 43 of Set 26 | rocha
# Processing Record 44 of Set 26 | ituni
# City not found. Skipping...
# Processing Record 45 of Set 26 | bodden town
# Processing Record 46 of Set 26 | le vauclin
# Processing Record 47 of Set 26 | guarapari
# Processing Record 48 of Set 26 | rio gallegos
# Processing Record 49 of Set 26 | richards bay
# Processing Record 50 of Set 26 | comodoro rivadavia
# Processing Record 1 of Set 27 | honningsvag
# Processing Record 2 of Set 27 | shache
# Processing Record 3 of Set 27 | mashhad
# Processing Record 4 of Set 27 | north myrtle beach
# Processing Record 5 of Set 27 | aspe
# Processing Record 6 of Set 27 | balykshi
# Processing Record 7 of Set 27 | challans
# Processing Record 8 of Set 27 | bilaspur
# Processing Record 9 of Set 27 | hwange
# Processing Record 10 of Set 27 | kunri
# Processing Record 11 of Set 27 | tres arroyos
# Processing Record 12 of Set 27 | bayonne
# Processing Record 13 of Set 27 | nantucket
# Processing Record 14 of Set 27 | poltavka
# Processing Record 15 of Set 27 | mahon
# Processing Record 16 of Set 27 | mayuge
# Processing Record 17 of Set 27 | bilma
# Processing Record 18 of Set 27 | fayaoue
# Processing Record 19 of Set 27 | puerto del rosario
# Processing Record 20 of Set 27 | gao
# Processing Record 21 of Set 27 | mitu
# Processing Record 22 of Set 27 | norrtalje
# Processing Record 23 of Set 27 | sabang
# Processing Record 24 of Set 27 | aykhal
# Processing Record 25 of Set 27 | blackwater
# Processing Record 26 of Set 27 | methven
# Processing Record 27 of Set 27 | uruacu
# Processing Record 28 of Set 27 | alyangula
# Processing Record 29 of Set 27 | khandyga
# Processing Record 30 of Set 27 | payo
# Processing Record 31 of Set 27 | log
# Processing Record 32 of Set 27 | buchanan
# Processing Record 33 of Set 27 | san andres
# Processing Record 34 of Set 27 | caraballeda
# Processing Record 35 of Set 27 | myatlevo
# Processing Record 36 of Set 27 | ifanadiana
# Processing Record 37 of Set 27 | burns lake
# Processing Record 38 of Set 27 | nadym
# Processing Record 39 of Set 27 | pacasmayo
# Processing Record 40 of Set 27 | mogadishu
# Processing Record 41 of Set 27 | karratha
# Processing Record 42 of Set 27 | kagoro
# Processing Record 43 of Set 27 | tuatapere
# Processing Record 44 of Set 27 | chichica
# Processing Record 45 of Set 27 | cabedelo
# Processing Record 46 of Set 27 | copiapo
# Processing Record 47 of Set 27 | iberia
# Processing Record 48 of Set 27 | agnibilekrou
# Processing Record 49 of Set 27 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 27 | londoko
# Processing Record 1 of Set 28 | tautira
# Processing Record 2 of Set 28 | auki
# Processing Record 3 of Set 28 | athabasca
# Processing Record 4 of Set 28 | bayangol
# Processing Record 5 of Set 28 | lira
# Processing Record 6 of Set 28 | aldan
# Processing Record 7 of Set 28 | lazo
# Processing Record 8 of Set 28 | damghan
# Processing Record 9 of Set 28 | novyy urengoy
# Processing Record 10 of Set 28 | cap malheureux
# Processing Record 11 of Set 28 | abu dhabi
# Processing Record 12 of Set 28 | strezhevoy
# Processing Record 13 of Set 28 | limenaria
# Processing Record 14 of Set 28 | kargopol
# Processing Record 15 of Set 28 | dhilwan
# Processing Record 16 of Set 28 | snyder
# Processing Record 17 of Set 28 | geraldton
# Processing Record 18 of Set 28 | nhulunbuy
# Processing Record 19 of Set 28 | laredo
# Processing Record 20 of Set 28 | mahajanga
# Processing Record 21 of Set 28 | valleyview
# Processing Record 22 of Set 28 | ashcroft
# Processing Record 23 of Set 28 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 28 | chahal
# Processing Record 25 of Set 28 | liverpool
# Processing Record 26 of Set 28 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 28 | weihe
# Processing Record 28 of Set 28 | abonnema
# Processing Record 29 of Set 28 | usinsk
# Processing Record 30 of Set 28 | datong
# Processing Record 31 of Set 28 | la asuncion
# Processing Record 32 of Set 28 | verkhnetulomskiy
# Processing Record 33 of Set 28 | at-bashi
# Processing Record 34 of Set 28 | coihaique
# Processing Record 35 of Set 28 | aflu
# City not found. Skipping...
# Processing Record 36 of Set 28 | telford
# Processing Record 37 of Set 28 | asau
# Processing Record 38 of Set 28 | faya
# Processing Record 39 of Set 28 | esmeraldas
# Processing Record 40 of Set 28 | wardha
# Processing Record 41 of Set 28 | anadyr
# Processing Record 42 of Set 28 | sartell
# Processing Record 43 of Set 28 | kijang
# Processing Record 44 of Set 28 | bayeux
# Processing Record 45 of Set 28 | itaituba
# Processing Record 46 of Set 28 | balakovo
# Processing Record 47 of Set 28 | zhanakorgan
# Processing Record 48 of Set 28 | kayankulam
# Processing Record 49 of Set 28 | wagga wagga
# Processing Record 50 of Set 28 | uthal
# Processing Record 1 of Set 29 | andra
# Processing Record 2 of Set 29 | tual
# Processing Record 3 of Set 29 | salinopolis
# Processing Record 4 of Set 29 | viamao
# Processing Record 5 of Set 29 | swan hill
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the date
city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Append Column Names
city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind, 
                          "Current Description": city_weather_description})

# %%
#Add the data to a new dataframe
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Terekli-Mekteb      RU  44.1671   45.8698     66.34        42          48
# 1  Port Elizabeth      ZA -33.9180   25.5701     67.10        78          75
# 2   Ponta Delgada      PT  37.7333  -25.6667     61.52        67          40
# 3          Atuona      PF  -9.8000 -139.0333     78.84        79          20
# 4         Rikitea      PF -23.1203 -134.9692     78.89        74           6
# 5         Qaanaaq      GL  77.4840  -69.3632     -2.85        71           9
# 6          Dingle      PH  10.9995  122.6711     76.10        88         100
# 7           Tabou      CI   4.4230   -7.3528     86.07        69          92
# 8    Punta Arenas      CL -53.1500  -70.9167     41.11       100          75
# 9        Waingapu      ID  -9.6567  120.2641     78.82        83          96
#
#    Wind Speed Current Description
# 0        5.53    scattered clouds
# 1       13.80       broken clouds
# 2       28.77    scattered clouds
# 3       21.27          light rain
# 4       17.38           clear sky
# 5        5.97           clear sky
# 6        4.36     overcast clouds
# 7       10.54     overcast clouds
# 8        8.05       broken clouds
# 9        3.51     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="WeatherPy_Database.csv")
